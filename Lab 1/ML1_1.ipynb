# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
main_data= pd.read_csv("/content/drive/MyDrive/ML/Data_for_Transformation.csv")

# %%
print(main_data.head())
plt.scatter(main_data["Age"],main_data["Salary"])
plt.show()
# Out:
#    Country  Age  Salary Purchased
# 0   France   44   72000        No
# 1    Spain   27   48000       Yes
# 2  Germany   30   54000        No
# 3    Spain   38   61000        No
# 4  Germany   40   68000       Yes

# %%
plt.hist(main_data["Salary"],bins=10,color="Red")
plt.show()

# %%
fig_size=plt.figure(figsize=(10,5))
plt.bar(main_data["Country"],main_data["Salary"],color="Red")
plt.title("Country VS Salary")
plt.xlabel("Country")
plt.ylabel("Salary")
plt.show()
